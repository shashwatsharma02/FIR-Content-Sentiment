# %% [markdown]
# <a href="https://www.kaggle.com/code/shashwatcodesavvy/weapon-detection-yolo-filetuning?scriptVersionId=161333558" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.4/709.4 kB 11.5 MB/s eta 0:00:00
# ...

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.8 🚀 Python-3.10.12 torch-2.0.0+cpu CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5432.0/8062.4 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !yolo task=detect mode=train model=yolov8s.pt data = '/kaggle/input/weapon-detection/data.yaml' epochs=20 imgsz=224 plots=True
# Out:
# ...
# 100%|███████████████████████████████████████| 21.5M/21.5M [00:00<00:00, 191MB/s]
# Ultralytics YOLOv8.1.8 🚀 Python-3.10.12 torch-2.0.0+cpu CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo task=detect mode=predict model= "/kaggle/working/runs/detect/train/weights/best.pt" conf=0.25 source= "/kaggle/input/weapon-detection/valid/images/*"
# Out:
# Ultralytics YOLOv8.1.8 🚀 Python-3.10.12 torch-2.0.0+cpu CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11127132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/905 /kaggle/input/weapon-detection/valid/images/grenade1280_jpg.rf.2800334870d7cb9c79ac8af73f887ed3.jpg: 224x224 1 grenade, 162.8ms
# image 2/905 /kaggle/input/weapon-detection/valid/images/grenade1281_jpg.rf.cb21906b7687724a3060c82c50a114ce.jpg: 224x224 1 grenade, 88.5ms
# image 3/905 /kaggle/input/weapon-detection/valid/images/grenade1282_jpg.rf.2cd765967c5a6b93a61f3e9413f49f40.jpg: 224x224 1 grenade, 70.3ms
# image 4/905 /kaggle/input/weapon-detection/valid/images/grenade1283_jpg.rf.00c9fa77bd1c1643d942baf83e8174b2.jpg: 224x224 1 grenade, 1 knife, 70.1ms
# image 5/905 /kaggle/input/weapon-detection/valid/images/grenade1285_jpg.rf.6539e989e7ae145b544848ae5987301a.jpg: 224x224 1 grenade, 68.6ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('/kaggle/working/runs/detect/predict/*.jpg')[:10]:
    display(Image(filename=image_path, width=600))
    print("\n")
